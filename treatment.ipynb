# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv(r"/Users/kuberdutta/Downloads/employee_train.csv")

# %%
df
# Out:
#       S.No        Timestamp  Age  Gender         Country state self_employed  \
# 0        1  8/27/2014 11:29   37  Female   United States    IL           NaN
# 1        2  8/27/2014 11:29   44       M   United States    IN           NaN
# 2        3  8/27/2014 11:29   32    Male          Canada   NaN           NaN
# 3        4  8/27/2014 11:29   31    Male  United Kingdom   NaN           NaN
# 4        5  8/27/2014 11:30   31    Male   United States    TX           NaN
# ...    ...              ...  ...     ...             ...   ...           ...
# 1043  1044  8/29/2014 11:20   26    Male   United States    WA            No
# 1044  1045  8/29/2014 11:22   29       f  United Kingdom   NaN            No
# 1045  1046  8/29/2014 11:23   26  Female          Canada   NaN            No
# 1046  1047  8/29/2014 11:24   33    Malr           Italy   NaN            No
# 1047  1048  8/29/2014 11:25   28    Male          Brazil   NaN            No
#
# ...

# %%
df.columns
# Out:
# Index(['S.No', 'Timestamp', 'Age', 'Gender', 'Country', 'state',
#        'self_employed', 'family_history', 'treatment', 'work_interfere',
#        'no_employees', 'remote_work', 'tech_company', 'benefits',
#        'care_options', 'wellness_program', 'seek_help', 'anonymity', 'leave',
#        'mental_health_consequence', 'phys_health_consequence', 'coworkers',
#        'supervisor', 'mental_health_interview', 'phys_health_interview',
#        'mental_vs_physical', 'obs_consequence', 'comments'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048 entries, 0 to 1047
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   S.No                       1048 non-null   int64
#  1   Timestamp                  1048 non-null   object
#  2   Age                        1048 non-null   int64
#  3   Gender                     1048 non-null   object
#  4   Country                    1048 non-null   object
#  5   state                      636 non-null    object
#  6   self_employed              1030 non-null   object
#  7   family_history             1048 non-null   object
#  8   treatment                  1048 non-null   object
#  9   work_interfere             812 non-null    object
#  10  no_employees               1048 non-null   object
#  11  remote_work                1048 non-null   object
#  12  tech_company               1048 non-null   object
# ...

# %%
df.shape
# Out:
# (1048, 28)

# %%
df.isnull().sum() # number of null values in each column
# Out:
# S.No                           0
# Timestamp                      0
# Age                            0
# Gender                         0
# Country                        0
# state                        412
# self_employed                 18
# family_history                 0
# treatment                      0
# work_interfere               236
# no_employees                   0
# remote_work                    0
# tech_company                   0
# benefits                      13
# care_options                   0
# wellness_program               4
# seek_help                      0
# anonymity                      0
# leave                          4
# mental_health_consequence      0
# phys_health_consequence        0
# coworkers                      0
# supervisor                     0
# mental_health_interview        0
# phys_health_interview          0
# mental_vs_physical             0
# obs_consequence                0
# comments                     916
# dtype: int64

# %%
df.columns
# Out:
# Index(['S.No', 'Timestamp', 'Age', 'Gender', 'Country', 'state',
#        'self_employed', 'family_history', 'treatment', 'work_interfere',
#        'no_employees', 'remote_work', 'tech_company', 'benefits',
#        'care_options', 'wellness_program', 'seek_help', 'anonymity', 'leave',
#        'mental_health_consequence', 'phys_health_consequence', 'coworkers',
#        'supervisor', 'mental_health_interview', 'phys_health_interview',
#        'mental_vs_physical', 'obs_consequence', 'comments'],
#       dtype='object')

# %%
df.shape
# Out:
# (1048, 28)

# %%
df.isnull().sum()
# Out:
# S.No                           0
# Timestamp                      0
# Age                            0
# Gender                         0
# Country                        0
# state                        412
# self_employed                 18
# family_history                 0
# treatment                      0
# work_interfere               236
# no_employees                   0
# remote_work                    0
# tech_company                   0
# benefits                      13
# care_options                   0
# wellness_program               4
# seek_help                      0
# anonymity                      0
# leave                          4
# mental_health_consequence      0
# phys_health_consequence        0
# coworkers                      0
# supervisor                     0
# mental_health_interview        0
# phys_health_interview          0
# mental_vs_physical             0
# obs_consequence                0
# comments                     916
# dtype: int64

# %%
df['state'].value_counts()
# Out:
# state
# CA    123
# WA     60
# NY     49
# TN     39
# TX     38
# OR     26
# PA     26
# OH     24
# IL     21
# IN     20
# MA     20
# MI     19
# MN     17
# VA     12
# GA     12
# MO     12
# NC     10
# WI     10
# FL     10
# CO      9
# AZ      7
# MD      7
# UT      6
# OK      5
# KY      5
# AL      4
# IA      4
# DC      4
# CT      4
# SC      4
# SD      3
# KS      3
# NH      3
# NV      3
# NJ      3
# VT      2
# WY      2
# NM      2
# NE      2
# WV      1
# ID      1
# MS      1
# RI      1
# LA      1
# ME      1
# Name: count, dtype: int64

# %%
df['state'].fillna('Unknown', inplace=True)

# %%
df.isnull().sum()
# Out:
# S.No                           0
# Timestamp                      0
# Age                            0
# Gender                         0
# Country                        0
# state                          0
# self_employed                 18
# family_history                 0
# treatment                      0
# work_interfere               236
# no_employees                   0
# remote_work                    0
# tech_company                   0
# benefits                      13
# care_options                   0
# wellness_program               4
# seek_help                      0
# anonymity                      0
# leave                          4
# mental_health_consequence      0
# phys_health_consequence        0
# coworkers                      0
# supervisor                     0
# mental_health_interview        0
# phys_health_interview          0
# mental_vs_physical             0
# obs_consequence                0
# comments                     916
# dtype: int64

# %%
df['state']
# Out:
# 0            IL
# 1            IN
# 2       Unknown
# 3       Unknown
# 4            TX
#          ...
# 1043         WA
# 1044    Unknown
# 1045    Unknown
# 1046    Unknown
# 1047    Unknown
# Name: state, Length: 1048, dtype: object

# %% [markdown]
# # Handling null values

# %%
df['self_employed'].fillna(df['self_employed'].mode()[0],inplace=True)

# %%
df.isnull().sum()
# Out:
# S.No                           0
# Timestamp                      0
# Age                            0
# Gender                         0
# Country                        0
# state                          0
# self_employed                  0
# family_history                 0
# treatment                      0
# work_interfere               236
# no_employees                   0
# remote_work                    0
# tech_company                   0
# benefits                      13
# care_options                   0
# wellness_program               4
# seek_help                      0
# anonymity                      0
# leave                          4
# mental_health_consequence      0
# phys_health_consequence        0
# coworkers                      0
# supervisor                     0
# mental_health_interview        0
# phys_health_interview          0
# mental_vs_physical             0
# obs_consequence                0
# comments                     916
# dtype: int64

# %%
df['benefits'].fillna(df['benefits'].mode()[0],inplace=True)

# %%
df['work_interfere'].fillna(df['work_interfere'].mode()[0],inplace=True)

# %%
df['wellness_program'].fillna(df['wellness_program'].mode()[0],inplace=True)

# %%
df['leave'].fillna(df['leave'].mode()[0],inplace=True)

# %%
df.isnull().sum().sum()
# Out:
# 916

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048 entries, 0 to 1047
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   S.No                       1048 non-null   int64
#  1   Timestamp                  1048 non-null   object
#  2   Age                        1048 non-null   int64
#  3   Gender                     1048 non-null   object
#  4   Country                    1048 non-null   object
#  5   state                      1048 non-null   object
#  6   self_employed              1048 non-null   object
#  7   family_history             1048 non-null   object
#  8   treatment                  1048 non-null   object
#  9   work_interfere             1048 non-null   object
#  10  no_employees               1048 non-null   object
#  11  remote_work                1048 non-null   object
#  12  tech_company               1048 non-null   object
# ...

# %%
df.select_dtypes(include='object').columns
# Out:
# Index(['Timestamp', 'Gender', 'Country', 'state', 'self_employed',
#        'family_history', 'treatment', 'work_interfere', 'no_employees',
#        'remote_work', 'tech_company', 'benefits', 'care_options',
#        'wellness_program', 'seek_help', 'anonymity', 'leave',
#        'mental_health_consequence', 'phys_health_consequence', 'coworkers',
#        'supervisor', 'mental_health_interview', 'phys_health_interview',
#        'mental_vs_physical', 'obs_consequence', 'comments'],
#       dtype='object')

# %%
for columns in df.columns:
    if(df[columns].dtype=='object'):
        print(columns+' '+str(len(df[columns].unique())))
# Out:
# Timestamp 679
# Gender 45
# Country 42
# state 46
# self_employed 2
# family_history 2
# treatment 2
# work_interfere 4
# no_employees 6
# remote_work 2
# tech_company 2
# benefits 3
# care_options 3
# wellness_program 3
# seek_help 3
# anonymity 3
# leave 5
# mental_health_consequence 3
# phys_health_consequence 3
# coworkers 3
# supervisor 3
# mental_health_interview 3
# phys_health_interview 3
# mental_vs_physical 3
# obs_consequence 2
# comments 129

# %%
len(df['Gender'].value_counts())
# Out:
# 45

# %% [markdown]
# # Class inbalance

# %%
df['self_employed'].value_counts()
# Out:
# self_employed
# No     924
# Yes    124
# Name: count, dtype: int64

# %%
df['self_employed'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df['obs_consequence'].value_counts()
# Out:
# obs_consequence
# No     1531
# Yes     317
# Name: count, dtype: int64

# %%
df['obs_consequence'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
print(df['obs_consequence'].value_counts())
# Out:
# obs_consequence
# No     1531
# Yes    1531
# Name: count, dtype: int64

# %%
df['obs_consequence'].value_counts()
# Out:
# obs_consequence
# No     1531
# Yes    1531
# Name: count, dtype: int64

# %%
df['tech_company'].value_counts()
# Out:
# tech_company
# Yes    2653
# No     2653
# Name: count, dtype: int64

# %%
df['obs_consequence'].value_counts()
# Out:
# obs_consequence
# Yes    2668
# No     2638
# Name: count, dtype: int64

# %%
df['treatment'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # Encoding

# %%
# Handle missing values in the 'comments' column
df['comments'] = df['comments'].fillna("no comment")

# %%
# Define keywords related to mental health issues
mental_health_keywords = [
    "depression", "anxiety", "panic attack", "bipolar", "mental health", 
    "stress", "burnout", "suicidal", "therapy", "counseling", "medication", 
    "antidepressant", "mental illness", "PTSD", "insomnia", "schizophrenia", 
    "psychosis", "self-harm", "addiction", "drug use"
]

# Function to assign scores based on comment content
def assign_mental_health_score(comment):
    comment_lower = comment.lower()  # Convert to lowercase for case-insensitive matching
    score = sum(1 for keyword in mental_health_keywords if keyword in comment_lower)  # Count matches
    
    # Normalize score (higher matches = higher score)
    if score > 5:
        return 10  # Severe mental health concern
    elif score > 2:
        return 7  # Moderate concern
    elif score > 0:
        return 5  # Mild concern
    else:
        return 0  # No mental health indicators

# Apply function to comments
df["COMMENT"] = df["comments"].apply(assign_mental_health_score)

# %%
df.drop('comments', axis=1, inplace=True)

# %%
df['remote_work'] = df['remote_work'].replace('No',0)
df['remote_work'] = df['remote_work'].replace('Yes',1)

# %%
df['treatment'] = df['treatment'].replace('No',0)
df['treatment'] = df['treatment'].replace('Yes',1)

# %%
df['family_history'] = df['family_history'].replace('No',0)
df['family_history'] = df['family_history'].replace('Yes',1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5306 entries, 0 to 5305
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   S.No                       5306 non-null   int64
#  1   Timestamp                  5306 non-null   object
#  2   Age                        5306 non-null   int64
#  3   Gender                     5306 non-null   object
#  4   Country                    5306 non-null   object
#  5   state                      5306 non-null   object
#  6   self_employed              5306 non-null   object
#  7   family_history             5306 non-null   int64
#  8   treatment                  5306 non-null   int64
#  9   work_interfere             5306 non-null   object
#  10  no_employees               5306 non-null   object
#  11  remote_work                5306 non-null   int64
#  12  tech_company               5306 non-null   object
# ...

# %%
df.select_dtypes(include='object').columns
# Out:
# Index(['Timestamp', 'Gender', 'Country', 'state', 'self_employed',
#        'work_interfere', 'no_employees', 'tech_company', 'benefits',
#        'care_options', 'wellness_program', 'seek_help', 'anonymity', 'leave',
#        'mental_health_consequence', 'phys_health_consequence', 'coworkers',
#        'supervisor', 'mental_health_interview', 'phys_health_interview',
#        'mental_vs_physical', 'obs_consequence'],
#       dtype='object')

# %%
for columns in df.columns:
    if(df[columns].dtype=='object'):
        print(columns+' '+str(len(df[columns].unique())))
# Out:
# Timestamp 679
# Gender 45
# Country 42
# state 46
# self_employed 2
# work_interfere 4
# no_employees 6
# tech_company 2
# benefits 3
# care_options 3
# wellness_program 3
# seek_help 3
# anonymity 3
# leave 5
# mental_health_consequence 3
# phys_health_consequence 3
# coworkers 3
# supervisor 3
# mental_health_interview 3
# phys_health_interview 3
# mental_vs_physical 3
# obs_consequence 2

# %%
df['self_employed'] = df['self_employed'].replace('No',0)
df['self_employed'] = df['self_employed'].replace('Yes',1)

# %%
for columns in df.columns:
    if(df[columns].dtype=='object'):
        print(columns+' '+str(len(df[columns].unique())))
# Out:
# Timestamp 679
# Gender 45
# Country 42
# state 46
# work_interfere 4
# no_employees 6
# tech_company 2
# benefits 3
# care_options 3
# wellness_program 3
# seek_help 3
# anonymity 3
# leave 5
# mental_health_consequence 3
# phys_health_consequence 3
# coworkers 3
# supervisor 3
# mental_health_interview 3
# phys_health_interview 3
# mental_vs_physical 3
# obs_consequence 2

# %%
df['tech_company'] = df['tech_company'].replace('No',0)
df['tech_company'] = df['tech_company'].replace('Yes',1)

# %%
for columns in df.columns:
    if(df[columns].dtype=='object'):
        print(columns+' '+str(len(df[columns].unique())))
# Out:
# Timestamp 679
# Gender 45
# Country 42
# state 46
# work_interfere 4
# no_employees 6
# benefits 3
# care_options 3
# wellness_program 3
# seek_help 3
# anonymity 3
# leave 5
# mental_health_consequence 3
# phys_health_consequence 3
# coworkers 3
# supervisor 3
# mental_health_interview 3
# phys_health_interview 3
# mental_vs_physical 3
# obs_consequence 2

# %%
df['obs_consequence'] = df['obs_consequence'].replace('No',0)
df['obs_consequence'] = df['obs_consequence'].replace('Yes',1)

# %%
for columns in df.columns:
    if(df[columns].dtype=='object'):
        print(columns+' '+str(len(df[columns].unique())))
# Out:
# Timestamp 679
# Gender 45
# Country 42
# state 46
# work_interfere 4
# no_employees 6
# benefits 3
# care_options 3
# wellness_program 3
# seek_help 3
# anonymity 3
# leave 5
# mental_health_consequence 3
# phys_health_consequence 3
# coworkers 3
# supervisor 3
# mental_health_interview 3
# phys_health_interview 3
# mental_vs_physical 3

# %%
df['leave'].value_counts() # we have to do ordinal encoding
# Out:
# leave
# Don't know            1698
# Somewhat difficult    1336
# Somewhat easy          872
# Very easy              798
# Very difficult         602
# Name: count, dtype: int64

# %%
df['Country'].value_counts()
# Out:
# Country
# United States             2437
# United Kingdom             975
# Germany                    642
# Canada                     339
# Netherlands                 95
# Australia                   94
# India                       90
# South Africa                81
# Ireland                     76
# New Zealand                 65
# Belgium                     55
# Poland                      50
# France                      36
# Bahamas, The                34
# Denmark                     27
# Zimbabwe                    26
# Italy                       24
# Croatia                     24
# Japan                       18
# Brazil                      14
# Austria                     12
# Switzerland                 12
# Israel                      11
# Mexico                      10
# Finland                     10
# Hungary                      9
# Bosnia and Herzegovina       8
# Romania                      7
# Sweden                       6
# Russia                       3
# ...

# %%
# frequency encoding

# %%
freq_encoding = df['Country'].value_counts()
df['Country'] = df['Country'].map(freq_encoding)

# %%
df['Country'].value_counts()
# Out:
# Country
# 2437    2437
# 975      975
# 642      642
# 339      339
# 95        95
# 94        94
# 90        90
# 81        81
# 76        76
# 65        65
# 55        55
# 50        50
# 24        48
# 36        36
# 34        34
# 27        27
# 26        26
# 12        24
# 10        20
# 18        18
# 14        14
# 11        11
# 9          9
# 2          8
# 8          8
# 1          8
# 7          7
# 6          6
# 3          3
# Name: count, dtype: int64

# %%
for columns in df.columns:
    if(df[columns].dtype=='object'):
        print(columns+' '+str(len(df[columns].unique())))
# Out:
# Timestamp 679
# Gender 45
# state 46
# work_interfere 4
# no_employees 6
# benefits 3
# care_options 3
# wellness_program 3
# seek_help 3
# anonymity 3
# leave 5
# mental_health_consequence 3
# phys_health_consequence 3
# coworkers 3
# supervisor 3
# mental_health_interview 3
# phys_health_interview 3
# mental_vs_physical 3

# %%
df['state'].value_counts()
# Out:
# state
# Unknown    2869
# CA          386
# WI          165
# WA          153
# IL          140
# TX          137
# TN          134
# VA          123
# NY          113
# PA          100
# MD           78
# MN           72
# FL           66
# IN           64
# MI           63
# OK           62
# IA           62
# GA           58
# OH           56
# MA           49
# OR           38
# CT           34
# NC           32
# MO           32
# LA           31
# UT           26
# KY           25
# AZ           16
# AL           16
# WV           13
# NM           12
# CO           11
# VT           10
# DC            8
# NE            8
# KS            8
# NH            7
# ID            6
# WY            4
# MS            4
# SC            4
# SD            3
# NJ            3
# NV            3
# RI            1
# ME            1
# Name: count, dtype: int64

# %%
# frequency encoding

# %%
freq_encoding = df['state'].value_counts()
df['state'] = df['state'].map(freq_encoding)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5306 entries, 0 to 5305
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   S.No                       5306 non-null   int64
#  1   Timestamp                  5306 non-null   object
#  2   Age                        5306 non-null   int64
#  3   Gender                     5306 non-null   object
#  4   Country                    5306 non-null   int64
#  5   state                      5306 non-null   int64
#  6   self_employed              5306 non-null   int64
#  7   family_history             5306 non-null   int64
#  8   treatment                  5306 non-null   int64
#  9   work_interfere             5306 non-null   object
#  10  no_employees               5306 non-null   object
#  11  remote_work                5306 non-null   int64
#  12  tech_company               5306 non-null   int64
# ...

# %%
for columns in df.columns:
    if(df[columns].dtype=='object'):
        print(columns+' '+str(len(df[columns].unique())))
# Out:
# Timestamp 679
# Gender 45
# work_interfere 4
# no_employees 6
# benefits 3
# care_options 3
# wellness_program 3
# seek_help 3
# anonymity 3
# leave 5
# mental_health_consequence 3
# phys_health_consequence 3
# coworkers 3
# supervisor 3
# mental_health_interview 3
# phys_health_interview 3
# mental_vs_physical 3

# %%
df['benefits'].value_counts()
# Out:
# benefits
# No            2445
# Yes           1710
# Don't know    1151
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
df['benefits'] = encoder.fit_transform(df['benefits'])

# %%
for columns in df.columns:
    if(df[columns].dtype=='object'):
        print(columns+' '+str(len(df[columns].unique())))
# Out:
# Timestamp 679
# Gender 45
# work_interfere 4
# no_employees 6
# care_options 3
# wellness_program 3
# seek_help 3
# anonymity 3
# leave 5
# mental_health_consequence 3
# phys_health_consequence 3
# coworkers 3
# supervisor 3
# mental_health_interview 3
# phys_health_interview 3
# mental_vs_physical 3

# %%
df['care_options'].value_counts()
# Out:
# care_options
# No          2268
# Yes         1972
# Not sure    1066
# Name: count, dtype: int64

# %%
encoder = LabelEncoder()
df['care_options'] = encoder.fit_transform(df['care_options'])

# %%
df['care_options']
# Out:
# 0       1
# 1       0
# 2       0
# 3       1
# 4       0
#        ..
# 5301    2
# 5302    0
# 5303    2
# 5304    0
# 5305    2
# Name: care_options, Length: 5306, dtype: int64

# %%
df.shape
# Out:
# (5306, 28)

# %%
for columns in df.columns:
    if(df[columns].dtype=='object'):
        print(columns+' '+str(len(df[columns].unique())))
# Out:
# Timestamp 679
# Gender 45
# work_interfere 4
# no_employees 6
# wellness_program 3
# seek_help 3
# anonymity 3
# leave 5
# mental_health_consequence 3
# phys_health_consequence 3
# coworkers 3
# supervisor 3
# mental_health_interview 3
# phys_health_interview 3
# mental_vs_physical 3

# %%
df['wellness_program'].value_counts()
# Out:
# wellness_program
# No            3572
# Yes           1086
# Don't know     648
# Name: count, dtype: int64

# %%
encoder = LabelEncoder()
df['wellness_program'] = encoder.fit_transform(df['wellness_program'])

# %%
for columns in df.columns:
    if(df[columns].dtype=='object'):
        print(columns+' '+str(len(df[columns].unique())))
# Out:
# Timestamp 679
# Gender 45
# work_interfere 4
# no_employees 6
# seek_help 3
# anonymity 3
# leave 5
# mental_health_consequence 3
# phys_health_consequence 3
# coworkers 3
# supervisor 3
# mental_health_interview 3
# phys_health_interview 3
# mental_vs_physical 3

# %%
df['seek_help'].value_counts()
# Out:
# seek_help
# No            3063
# Yes           1133
# Don't know    1110
# Name: count, dtype: int64

# %%
encoder = LabelEncoder()
df['seek_help'] = encoder.fit_transform(df['seek_help'])

# %%
for columns in df.columns:
    if(df[columns].dtype=='object'):
        print(columns+' '+str(len(df[columns].unique())))
# Out:
# Timestamp 679
# Gender 45
# work_interfere 4
# no_employees 6
# anonymity 3
# leave 5
# mental_health_consequence 3
# phys_health_consequence 3
# coworkers 3
# supervisor 3
# mental_health_interview 3
# phys_health_interview 3
# mental_vs_physical 3

# %%
df['anonymity'].value_counts()
# Out:
# anonymity
# Don't know    3202
# Yes           1569
# No             535
# Name: count, dtype: int64

# %%
encoder = LabelEncoder()
df['anonymity'] = encoder.fit_transform(df['anonymity'])

# %%
for columns in df.columns:
    if(df[columns].dtype=='object'):
        print(columns+' '+str(len(df[columns].unique())))
# Out:
# Timestamp 679
# Gender 45
# work_interfere 4
# no_employees 6
# leave 5
# mental_health_consequence 3
# phys_health_consequence 3
# coworkers 3
# supervisor 3
# mental_health_interview 3
# phys_health_interview 3
# mental_vs_physical 3

# %%
df['mental_health_consequence'].value_counts()
# Out:
# mental_health_consequence
# Yes      1949
# Maybe    1760
# No       1597
# Name: count, dtype: int64

# %%
encoder = LabelEncoder()
df['mental_health_consequence'] = encoder.fit_transform(df['mental_health_consequence'])

# %%
df['phys_health_consequence'].value_counts()
# Out:
# phys_health_consequence
# No       3101
# Maybe    1446
# Yes       759
# Name: count, dtype: int64

# %%
encoder = LabelEncoder()
df['phys_health_consequence'] = encoder.fit_transform(df['phys_health_consequence'])

# %%
for columns in df.columns:
    if(df[columns].dtype=='object'):
        print(columns+' '+str(len(df[columns].unique())))
# Out:
# Timestamp 679
# Gender 45
# work_interfere 4
# no_employees 6
# leave 5
# coworkers 3
# supervisor 3
# mental_health_interview 3
# phys_health_interview 3
# mental_vs_physical 3

# %%
df['coworkers'].value_counts()
# Out:
# coworkers
# Some of them    3116
# No              1277
# Yes              913
# Name: count, dtype: int64

# %%
encoder = LabelEncoder()
df['coworkers'] = encoder.fit_transform(df['coworkers'])

# %%
df['supervisor'].value_counts()
# Out:
# supervisor
# No              2034
# Yes             1785
# Some of them    1487
# Name: count, dtype: int64

# %%
encoder = LabelEncoder()
df['supervisor'] = encoder.fit_transform(df['supervisor'])

# %%
for columns in df.columns:
    if(df[columns].dtype=='object'):
        print(columns+' '+str(len(df[columns].unique())))
# Out:
# Timestamp 679
# Gender 45
# work_interfere 4
# no_employees 6
# leave 5
# mental_health_interview 3
# phys_health_interview 3
# mental_vs_physical 3

# %%
df['mental_health_interview'].value_counts()
# Out:
# mental_health_interview
# No       3938
# Maybe    1127
# Yes       241
# Name: count, dtype: int64

# %%
encoder = LabelEncoder()
df['mental_health_interview'] = encoder.fit_transform(df['mental_health_interview'])

# %%
df['phys_health_interview'].value_counts()
# Out:
# phys_health_interview
# No       2217
# Maybe    2084
# Yes      1005
# Name: count, dtype: int64

# %%
encoder = LabelEncoder()
df['phys_health_interview'] = encoder.fit_transform(df['phys_health_interview'])

# %%
df['mental_vs_physical'].value_counts()
# Out:
# mental_vs_physical
# No            1824
# Yes           1775
# Don't know    1707
# Name: count, dtype: int64

# %%
encoder = LabelEncoder()
df['mental_vs_physical'] = encoder.fit_transform(df['mental_vs_physical'])

# %%
for columns in df.columns:
    if(df[columns].dtype=='object'):
        print(columns+' '+str(len(df[columns].unique())))
# Out:
# Timestamp 679
# Gender 45
# work_interfere 4
# no_employees 6
# leave 5

# %%
df['no_employees'].value_counts()
# Out:
# no_employees
# 5-Jan             1753
# More than 1000    1081
# 25-Jun             974
# 26-100             700
# 100-500            572
# 500-1000           226
# Name: count, dtype: int64

# %%
df['leave'].value_counts()
# Out:
# leave
# Don't know            1698
# Somewhat difficult    1336
# Somewhat easy          872
# Very easy              798
# Very difficult         602
# Name: count, dtype: int64

# %%
df['work_interfere'].value_counts()
# Out:
# work_interfere
# Sometimes    2790
# Rarely       1099
# Often         811
# Never         606
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import OrdinalEncoder

# Define the order of categories
categories = [['Sometimes','Unknown','Never','Rarely','Often']]

# Initialize Encoder
encoder = OrdinalEncoder(categories=categories)

# Fit and Transform
df['work_interfere'] = encoder.fit_transform(df[['work_interfere']])

# %%
df['work_interfere']
# Out:
# 0       4.0
# 1       3.0
# 2       2.0
# 3       0.0
# 4       0.0
#        ...
# 5301    3.0
# 5302    0.0
# 5303    0.0
# 5304    3.0
# 5305    4.0
# Name: work_interfere, Length: 5306, dtype: float64

# %%
for columns in df.columns:
    if(df[columns].dtype=='object'):
        print(columns+' '+str(len(df[columns].unique())))
# Out:
# Timestamp 679
# Gender 45
# no_employees 6
# leave 5

# %%
df['leave'].value_counts()
# Out:
# leave
# Don't know            1698
# Somewhat difficult    1336
# Somewhat easy          872
# Very easy              798
# Very difficult         602
# Name: count, dtype: int64

# %%
encoder = LabelEncoder()
df['leave'] = encoder.fit_transform(df['leave'])

# %%
for columns in df.columns:
    if(df[columns].dtype=='object'):
        print(columns+' '+str(len(df[columns].unique())))
# Out:
# Timestamp 679
# Gender 45
# no_employees 6

# %%
df['no_employees'].value_counts()
# Out:
# no_employees
# 5-Jan             1753
# More than 1000    1081
# 25-Jun             974
# 26-100             700
# 100-500            572
# 500-1000           226
# Name: count, dtype: int64

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male                        2016
# male                        1472
# Female                       492
# M                            344
# female                       261
# f                            175
# m                            113
# F                             99
# cis-female/femme              86
# Neuter                        46
# Female (trans)                36
# A little about you            34
# All                           26
# Mal                           13
# Nah                           10
# Woman                         10
# Cis Female                     9
# Guy (-ish) ^_^                 7
# queer                          6
# Female (cis)                   6
# Androgyne                      5
# male leaning androgynous       4
# Trans woman                    4
# Make                           4
# woman                          3
# cis male                       3
# Female                         2
# Cis Male                       2
# ...

# %%
# Define gender mapping
gender_mapping = {
    'Male': 0, 'M': 0, 'm': 0, 'male': 0, 'Man': 0, 'msle': 0, 'Mail': 0, 'Mal': 0, 'Make': 0, 'Male-ish': 0, 
    'Male (CIS)': 0, 'cis male': 0, 'Malr': 0, 'maile': 0,

    'Female': 1, 'F': 1, 'f': 1, 'female': 1, 'Woman': 1, 'woman': 1, 'Femake': 1, 'Cis Female': 1, 
    'Female ': 1, 'Female (cis)': 1, 'cis-female/femme': 1,

    'Non-binary': 2, 'Genderqueer': 2, 'fluid': 2, 'Trans-female': 2, 'Trans woman': 2, 'Female (trans)': 2, 
    'queer': 2, 'queer/she/they': 2, 'Androgyne': 2, 'Agender': 2, 'Enby': 2, 'Nah': 2, 'All': 2, 
    'A little about you': 2, 'something kinda male?': 2, 'male leaning androgynous': 2, 'Guy (-ish) ^_^': 2
}

# Apply mapping to Gender column (defaulting unknown values to 2)
df['Gender'] = df['Gender'].map(gender_mapping).fillna(2).astype(int)

# %%
df['Gender'].value_counts()
# Out:
# Gender
# 0    3973
# 1    1144
# 2     189
# Name: count, dtype: int64

# %%
encoder = LabelEncoder()
df['Gender'] = encoder.fit_transform(df['Gender'])

# %%
for columns in df.columns:
    if(df[columns].dtype=='object'):
        print(columns+' '+str(len(df[columns].unique())))
# Out:
# Timestamp 679
# no_employees 6

# %%
df['Timestamp'].value_counts()
# Out:
# Timestamp
# 8/27/2014 14:32    449
# 8/27/2014 22:55     86
# 8/28/2014 17:33     80
# 8/28/2014 16:52     74
# 8/27/2014 11:34     62
#                   ...
# 8/28/2014 9:58       1
# 8/28/2014 9:55       1
# 8/28/2014 9:40       1
# 8/28/2014 9:18       1
# 8/28/2014 0:43       1
# Name: count, Length: 679, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5306 entries, 0 to 5305
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   S.No                       5306 non-null   int64
#  1   Timestamp                  5306 non-null   object
#  2   Age                        5306 non-null   int64
#  3   Gender                     5306 non-null   int64
#  4   Country                    5306 non-null   int64
#  5   state                      5306 non-null   int64
#  6   self_employed              5306 non-null   int64
#  7   family_history             5306 non-null   int64
#  8   treatment                  5306 non-null   int64
#  9   work_interfere             5306 non-null   float64
#  10  no_employees               5306 non-null   object
#  11  remote_work                5306 non-null   int64
#  12  tech_company               5306 non-null   int64
# ...

# %%
df['no_employees']
# Out:
# 0               25-Jun
# 1               25-Jun
# 2              100-500
# 3               25-Jun
# 4                5-Jan
#              ...
# 5301            25-Jun
# 5302            25-Jun
# 5303            26-100
# 5304             5-Jan
# 5305    More than 1000
# Name: no_employees, Length: 5306, dtype: object

# %%
employee_mapping = {
    '1-5': 1,
    '6-25': 2,
    '26-100': 3,
    '100-500': 4,
    '500-1000': 5,
    'More than 1000': 6,
    'Unknown': 0  # Only needed if you assigned 'Unknown' earlier
}

df['no_employees'] = df['no_employees'].map(employee_mapping)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5306 entries, 0 to 5305
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   S.No                       5306 non-null   int64
#  1   Timestamp                  5306 non-null   object
#  2   Age                        5306 non-null   int64
#  3   Gender                     5306 non-null   int64
#  4   Country                    5306 non-null   int64
#  5   state                      5306 non-null   int64
#  6   self_employed              5306 non-null   int64
#  7   family_history             5306 non-null   int64
#  8   treatment                  5306 non-null   int64
#  9   work_interfere             5306 non-null   float64
#  10  no_employees               2579 non-null   float64
#  11  remote_work                5306 non-null   int64
#  12  tech_company               5306 non-null   int64
# ...

# %%
df['no_employees'] = df['no_employees'].fillna(0).astype(int)

# %%
# Convert column 'no_employees' to integer
df['no_employees'] = df['no_employees'].astype(int)

# %%
for columns in df.columns:
    if(df[columns].dtype=='object'):
        print(columns+' '+str(len(df[columns].unique())))
# Out:
# Timestamp 679

# %%
for columns in df.columns:
    if(df[columns].dtype=='object'):
        print(columns+' '+str(len(df[columns].unique())))
# Out:
# Timestamp 679

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5306 entries, 0 to 5305
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   S.No                       5306 non-null   int64
#  1   Timestamp                  5306 non-null   object
#  2   Age                        5306 non-null   int64
#  3   Gender                     5306 non-null   int64
#  4   Country                    5306 non-null   int64
#  5   state                      5306 non-null   int64
#  6   self_employed              5306 non-null   int64
#  7   family_history             5306 non-null   int64
#  8   treatment                  5306 non-null   int64
#  9   work_interfere             5306 non-null   float64
#  10  no_employees               5306 non-null   int64
#  11  remote_work                5306 non-null   int64
#  12  tech_company               5306 non-null   int64
# ...

# %%
# Convert column 'work_interfere' to integer
df['work_interfere'] = df['work_interfere'].astype(int)

# %%
# Convert column 'no_employees' to integer
df['no_employees'] = df['no_employees'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5306 entries, 0 to 5305
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   S.No                       5306 non-null   int64
#  1   Timestamp                  5306 non-null   object
#  2   Age                        5306 non-null   int64
#  3   Gender                     5306 non-null   int64
#  4   Country                    5306 non-null   int64
#  5   state                      5306 non-null   int64
#  6   self_employed              5306 non-null   int64
#  7   family_history             5306 non-null   int64
#  8   treatment                  5306 non-null   int64
#  9   work_interfere             5306 non-null   int64
#  10  no_employees               5306 non-null   int64
#  11  remote_work                5306 non-null   int64
#  12  tech_company               5306 non-null   int64
# ...

# %%
df.shape
# Out:
# (5306, 28)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5306 entries, 0 to 5305
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   S.No                       5306 non-null   int64
#  1   Timestamp                  5306 non-null   object
#  2   Age                        5306 non-null   int64
#  3   Gender                     5306 non-null   int64
#  4   Country                    5306 non-null   int64
#  5   state                      5306 non-null   int64
#  6   self_employed              5306 non-null   int64
#  7   family_history             5306 non-null   int64
#  8   treatment                  5306 non-null   int64
#  9   work_interfere             5306 non-null   int64
#  10  no_employees               5306 non-null   int64
#  11  remote_work                5306 non-null   int64
#  12  tech_company               5306 non-null   int64
# ...

# %%
# Convert Timestamp to Datetime format
df["Timestamp"] = pd.to_datetime(df["Timestamp"], errors='coerce')

# Convert to Unix Timestamp (seconds since 1970)
df["Timestamp_int"] = df["Timestamp"].astype('int64') // 10**9  # Convert nanoseconds to seconds

# Drop original Timestamp column
df.drop(columns=["Timestamp"], inplace=True)

# %%
df.columns
# Out:
# Index(['S.No', 'Age', 'Gender', 'Country', 'state', 'self_employed',
#        'family_history', 'treatment', 'work_interfere', 'no_employees',
#        'remote_work', 'tech_company', 'benefits', 'care_options',
#        'wellness_program', 'seek_help', 'anonymity', 'leave',
#        'mental_health_consequence', 'phys_health_consequence', 'coworkers',
#        'supervisor', 'mental_health_interview', 'phys_health_interview',
#        'mental_vs_physical', 'obs_consequence', 'COMMENT', 'Timestamp_int'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5306 entries, 0 to 5305
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   S.No                       5306 non-null   int64
#  1   Age                        5306 non-null   int64
#  2   Gender                     5306 non-null   int64
#  3   Country                    5306 non-null   int64
#  4   state                      5306 non-null   int64
#  5   self_employed              5306 non-null   int64
#  6   family_history             5306 non-null   int64
#  7   treatment                  5306 non-null   int64
#  8   work_interfere             5306 non-null   int64
#  9   no_employees               5306 non-null   int64
#  10  remote_work                5306 non-null   int64
#  11  tech_company               5306 non-null   int64
#  12  benefits                   5306 non-null   int64
# ...

# %%
df.shape
# Out:
# (5306, 28)

# %%
from sklearn.feature_selection import RFE
from sklearn.ensemble import RandomForestClassifier  

X = df.drop("treatment", axis=1)  # Features
y = df["treatment"]  # Target variable

model = RandomForestClassifier()  # Choose a model
rfe = RFE(model, n_features_to_select=20)  # Keep top 20 features
X_rfe = rfe.fit_transform(X, y)

print("Selected Features:", X.columns[rfe.support_])  # Display selected features
# Out:
# Selected Features: Index(['S.No', 'Age', 'Gender', 'Country', 'state', 'family_history',
#        'work_interfere', 'no_employees', 'benefits', 'care_options',
#        'seek_help', 'leave', 'mental_health_consequence',
#        'phys_health_consequence', 'coworkers', 'supervisor',
#        'phys_health_interview', 'mental_vs_physical', 'obs_consequence',
#        'Timestamp_int'],
#       dtype='object')

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
import pandas as pd

X = df.drop("treatment", axis=1)  # Features (exclude target)

# Compute VIF for each feature
vif_data = pd.DataFrame()
vif_data["Feature"] = X.columns
vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

print(vif_data)  # Shows VIF values
# Out:
#                       Feature       VIF
# 0                        S.No  1.166755
# 1                         Age  1.203302
# 2                      Gender  1.310708
# 3                     Country  7.410344
# 4                       state  7.651988
# 5               self_employed  2.608250
# 6              family_history  1.214172
# 7              work_interfere  1.246452
# 8                no_employees  2.446539
# 9                 remote_work  1.755119
# 10               tech_company  1.372077
# 11                   benefits  1.437307
# 12               care_options  1.557645
# 13           wellness_program  1.511989
# 14                  seek_help  1.657066
# 15                  anonymity  1.474912
# 16                      leave  1.416925
# 17  mental_health_consequence  1.312420
# 18    phys_health_consequence  1.441316
# 19                  coworkers  1.777945
# 20                 supervisor  1.809759
# 21    mental_health_interview  1.584144
# ...

# %%
df2=df.drop(['Country','state','self_employed','remote_work','tech_company','obs_consequence','phys_health_consequence','mental_health_interview'],axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5306 entries, 0 to 5305
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   S.No                       5306 non-null   int64
#  1   Age                        5306 non-null   int64
#  2   Gender                     5306 non-null   int64
#  3   Country                    5306 non-null   int64
#  4   state                      5306 non-null   int64
#  5   self_employed              5306 non-null   int64
#  6   family_history             5306 non-null   int64
#  7   treatment                  5306 non-null   int64
#  8   work_interfere             5306 non-null   int64
#  9   no_employees               5306 non-null   int64
#  10  remote_work                5306 non-null   int64
#  11  tech_company               5306 non-null   int64
#  12  benefits                   5306 non-null   int64
# ...

# %%
df2
# Out:
#       S.No  Age  Gender  family_history  treatment  work_interfere  \
# 0        1   37       1               0          1               4
# 1        3   32       0               0          0               3
# 2        5   31       0               0          0               2
# 3        6   33       0               1          0               0
# 4        7   35       1               1          1               0
# ...    ...  ...     ...             ...        ...             ...
# 5301   612   42       0               0          0               3
# 5302   182   26       1               0          0               0
# 5303   873   41       0               0          0               0
# 5304   330   33       0               1          1               3
# 5305   760   21       0               0          1               4
#
#       no_employees  benefits  care_options  wellness_program  seek_help  \
# 0                0         2             1                 1          2
# ...

# %%
df2.columns
# Out:
# Index(['S.No', 'Age', 'Gender', 'family_history', 'treatment',
#        'work_interfere', 'no_employees', 'benefits', 'care_options',
#        'wellness_program', 'seek_help', 'anonymity', 'leave',
#        'mental_health_consequence', 'coworkers', 'supervisor',
#        'phys_health_interview', 'mental_vs_physical', 'COMMENT',
#        'Timestamp_int'],
#       dtype='object')

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5306 entries, 0 to 5305
# Data columns (total 20 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   S.No                       5306 non-null   int64
#  1   Age                        5306 non-null   int64
#  2   Gender                     5306 non-null   int64
#  3   family_history             5306 non-null   int64
#  4   treatment                  5306 non-null   int64
#  5   work_interfere             5306 non-null   int64
#  6   no_employees               5306 non-null   int64
#  7   benefits                   5306 non-null   int64
#  8   care_options               5306 non-null   int64
#  9   wellness_program           5306 non-null   int64
#  10  seek_help                  5306 non-null   int64
#  11  anonymity                  5306 non-null   int64
#  12  leave                      5306 non-null   int64
# ...

# %% [markdown]
# # SPLITTING INTO X AND Y

# %%
X=df2.drop('treatment',axis=1)

# %%
X
# Out:
#       S.No  Age  Gender  family_history  work_interfere  no_employees  \
# 0        1   37       1               0               4             0
# 1        3   32       0               0               3             0
# 2        5   31       0               0               2             4
# 3        6   33       0               1               0             0
# 4        7   35       1               1               0             0
# ...    ...  ...     ...             ...             ...           ...
# 5301   612   42       0               0               3             0
# 5302   182   26       1               0               0             0
# 5303   873   41       0               0               0             3
# 5304   330   33       0               1               3             0
# 5305   760   21       0               0               4             6
#
#       benefits  care_options  wellness_program  seek_help  anonymity  leave  \
# ...

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5306 entries, 0 to 5305
# Data columns (total 19 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   S.No                       5306 non-null   int64
#  1   Age                        5306 non-null   int64
#  2   Gender                     5306 non-null   int64
#  3   family_history             5306 non-null   int64
#  4   work_interfere             5306 non-null   int64
#  5   no_employees               5306 non-null   int64
#  6   benefits                   5306 non-null   int64
#  7   care_options               5306 non-null   int64
#  8   wellness_program           5306 non-null   int64
#  9   seek_help                  5306 non-null   int64
#  10  anonymity                  5306 non-null   int64
#  11  leave                      5306 non-null   int64
#  12  mental_health_consequence  5306 non-null   int64
# ...

# %%
Y=df2[['treatment']]

# %%
Y
# Out:
#       treatment
# 0             1
# 1             0
# 2             0
# 3             0
# 4             1
# ...         ...
# 5301          0
# 5302          0
# 5303          0
# 5304          1
# 5305          1
#
# [5306 rows x 1 columns]

# %% [markdown]
# # Train and Test split

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.30,random_state=42)

# %%
X_train
# Out:
#       S.No  Age  Gender  family_history  work_interfere  no_employees  \
# 4501   604   30       1               1               4             0
# 4487   891   42       0               1               0             0
# 330    472   58       0               0               3             6
# 3243   924   42       0               0               0             6
# 3557    13   42       1               1               0             3
# ...    ...  ...     ...             ...             ...           ...
# 3092   794   35       1               0               0             4
# 3772     2   44       0               0               3             6
# 5191   963   35       0               0               0             3
# 5226   330   33       0               1               3             0
# 860    362   34       0               1               3             3
#
#       benefits  care_options  wellness_program  seek_help  anonymity  leave  \
# ...

# %%
X_test
# Out:
#       S.No          Age  Gender  family_history  work_interfere  no_employees  \
# 811    898           34       0               0               0             0
# 4039   878           29       0               0               0             6
# 5239   330           33       0               1               3             0
# 3065   612           42       0               0               3             0
# 1864   391  99999999999       2               1               4             0
# ...    ...          ...     ...             ...             ...           ...
# 1068   217           30       0               0               4             0
# 5088   142           37       0               0               0             6
# 5041    26           35       0               1               0             6
# 3708   356           31       0               0               0             5
# 5168   561           65       0               0               0             0
#
# ...

# %%
Y_train
# Out:
#       treatment
# 4501          1
# 4487          0
# 330           1
# 3243          1
# 3557          1
# ...         ...
# 3092          1
# 3772          0
# 5191          1
# 5226          1
# 860           1
#
# [3714 rows x 1 columns]

# %%
Y_test
# Out:
#       treatment
# 811           1
# 4039          0
# 5239          1
# 3065          0
# 1864          1
# ...         ...
# 1068          1
# 5088          1
# 5041          1
# 3708          1
# 5168          0
#
# [1592 rows x 1 columns]

# %% [markdown]
# # Scaling

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler=MinMaxScaler()

# %%
X_train =scaler.fit_transform(X_train)

# %%
X_test=scaler.fit_transform(X_test)

# %%
Y_train=scaler.fit_transform(Y_train)

# %%
Y_test=scaler.fit_transform(Y_test)

# %% [markdown]
# # Model Fitting

# %%
from sklearn.linear_model import LogisticRegression

# %%
lg=LogisticRegression()

# %%
lg.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %%
y_predlg=lg.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix,classification_report

# %%
print(classification_report(Y_test,y_predlg))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.65      0.56      0.60       607
#          1.0       0.75      0.82      0.78       985
#
#     accuracy                           0.72      1592
#    macro avg       0.70      0.69      0.69      1592
# weighted avg       0.71      0.72      0.71      1592

# %%
pip install xgboost

# %%
pip install lightgbm

# %%
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.model_selection import GridSearchCV

# Define models
models = {
    "RandomForest": RandomForestClassifier(),
    "XGBoost": XGBClassifier(use_label_encoder=False, eval_metric='logloss'),
    "LightGBM": LGBMClassifier()
}

# Define parameter grids
param_grid = {
    "RandomForest": {"n_estimators": [100, 200], "max_depth": [10, 20]},
    "XGBoost": {"learning_rate": [0.01, 0.1], "n_estimators": [100, 200]},
    "LightGBM": {"learning_rate": [0.01, 0.1], "n_estimators": [100, 200]}
}

best_models = {}
best_params = {}

# Loop through models and perform Grid Search
for model_name, model in models.items():
    print(f"🔍 Tuning {model_name}...")

    grid_search = GridSearchCV(model, param_grid[model_name], scoring="f1", cv=5, verbose=1, n_jobs=-1)
    grid_search.fit(X_train, Y_train)

    best_models[model_name] = grid_search.best_estimator_
    best_params[model_name] = grid_search.best_params_

    print(f"✅ Best {model_name} Model: {grid_search.best_estimator_}")
    print(f"🎯 Best Parameters: {grid_search.best_params_}\n")

# Print final best parameters for each model
print("🚀 Final Best Parameters:", best_params)

# %%
from sklearn.svm import SVC

# %%
svc=SVC()

# %%
svc.fit(X_train,Y_train)

# %%
y_pred_svc=svc.predict(X_test)

# %%
print(classification_report(Y_test,y_pred_svc))

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt=DecisionTreeClassifier()

# %%
dt.fit(X_train,Y_train)

# %%
y_pred_dt=dt.predict(X_test)

# %%
print(classification_report(Y_test,y_pred_dt))

# %%
from imblearn.over_sampling import SMOTE
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# Apply SMOTE to the training data
smote = SMOTE(random_state=42)
X_train_res, Y_train_res = smote.fit_resample(X_train, Y_train)

# Train the model
model = RandomForestClassifier()
model.fit(X_train_res, Y_train_res)

# Evaluate the model
y_pred = model.predict(X_test)
print("Accuracy:", accuracy_score(Y_test, y_pred))

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Initialize the k-NN model
knn = KNeighborsClassifier(n_neighbors=3)  # You can adjust the number of neighbors (k)

# Train the model
knn.fit(X_train, Y_train)

# Make predictions
y_pred = knn.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(Y_test, y_pred)
print(f"Accuracy: {accuracy * 100:.2f}%")

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score
# Initialize the GBM model
gbm = GradientBoostingClassifier(
    n_estimators=100,  # Number of boosting stages
    learning_rate=0.1,  # Learning rate
    max_depth=3,  # Maximum depth of each tree
    random_state=42
)

# Train the model
gbm.fit(X_train, Y_train)

# Make predictions
y_pred = gbm.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(Y_test, y_pred)
print(f"Accuracy: {accuracy * 100:.2f}%")

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.metrics import accuracy_score




# Define Random Forest model
rf = RandomForestClassifier()

# Define hyperparameters for tuning
param_grid = {
    'n_estimators': [100, 200, 300],   # Number of trees
    'max_depth': [None, 10, 20],       # Maximum depth of trees
    'min_samples_split': [2, 5, 10],   # Minimum samples required to split a node
    'min_samples_leaf': [1, 2, 4]      # Minimum samples required at leaf node
}

# Perform Grid Search with Cross-Validation
grid_search = GridSearchCV(rf, param_grid, cv=5, n_jobs=-1, verbose=2)
grid_search.fit(X_train, Y_train)

# Get the best parameters
print("Best Hyperparameters:", grid_search.best_params_)

# Train the model with best parameters
best_rf = grid_search.best_estimator_
y_pred = best_rf.predict(X_test)

# Evaluate accuracy
accuracy = accuracy_score(Y_test, y_pred)
print("Accuracy Score:", accuracy)
